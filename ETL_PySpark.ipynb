# %%
#Instalamos PySpark
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.3)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)

# %%
#Importamos librerias necesarias
from pyspark.sql import SparkSession
from pyspark.sql.functions import col


# Crear una sesión de Spark
spark = SparkSession.builder \
    .appName("DataSet") \
    .getOrCreate()

# %%
#Creamos nuestro Data Frame llamandolo en la ubicacion donde esta y separandolo por ","
df = spark.read.csv("/content/drive/MyDrive/bike_sales_data_world_2013_2023.csv",sep=',', header=True, inferSchema=True)

# %%
#Mostramos el Schema de nuestro CSV para ver los valores de las columnas y sus nombres
df.printSchema()
# Out:
# root
#  |-- Date: date (nullable = true)
#  |-- Day: integer (nullable = true)
#  |-- Month: string (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Customer_Age: integer (nullable = true)
#  |-- Age_Group: string (nullable = true)
#  |-- Customer_Gender: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- Product_Category: string (nullable = true)
#  |-- Sub_Category: string (nullable = true)
#  |-- Product: string (nullable = true)
#  |-- Order_Quantity: integer (nullable = true)
#  |-- Unit_Cost: integer (nullable = true)
#  |-- Unit_Price: integer (nullable = true)
#  |-- Profit: integer (nullable = true)
#  |-- Cost: integer (nullable = true)
#  |-- Revenue: integer (nullable = true)
#  |-- Size: string (nullable = true)
#  |-- Color: string (nullable = true)
#  |-- Material: string (nullable = true)
#  |-- Warranty: string (nullable = true)
#  |-- Manufacturer: string (nullable = true)
#  |-- Rating: integer (nullable = true)
#  |-- Shipping_Weight: double (nullable = true)
#  |-- Delivery_Time: integer (nullable = true)
#  |-- Discount: integer (nullable = true)
#  |-- Eco_Friendly: boolean (nullable = true)
#  |-- Shipping_Cost: double (nullable = true)
#  |-- Shipping_Company: string (nullable = true)
#  |-- Shipping_Type: string (nullable = true)
#  |-- Insurance: string (nullable = true)
#  |-- Return_Policy: string (nullable = true)

# %%
#Mostramos el df completo para tener una guia de los datos que queremos
df.show()
# Out:
# +----------+---+---------+----+------------+--------------------+---------------+---------+----------------+----------------+------------+-------------------+--------------+---------+----------+------+----+-------+-----------+-----+------------+--------+--------------+------+---------------+-------------+--------+------------+-------------+----------------+-------------+---------+-------------+
# |      Date|Day|    Month|Year|Customer_Age|           Age_Group|Customer_Gender|  Country|           State|Product_Category|Sub_Category|            Product|Order_Quantity|Unit_Cost|Unit_Price|Profit|Cost|Revenue|       Size|Color|    Material|Warranty|  Manufacturer|Rating|Shipping_Weight|Delivery_Time|Discount|Eco_Friendly|Shipping_Cost|Shipping_Company|Shipping_Type|Insurance|Return_Policy|
# +----------+---+---------+----+------------+--------------------+---------------+---------+----------------+----------------+------------+-------------------+--------------+---------+----------+------+----+-------+-----------+-----+------------+--------+--------------+------+---------------+-------------+--------+------------+-------------+----------------+-------------+---------+-------------+
# |2017-11-26| 26| November|2017|          19|         Youth (<25)|              M|   Canada|British Columbia|     Accessories|  Bike Racks|Hitch Rack - 4-Bike|             8|       45|       120|   590| 360|    950|Extra Large|White|     Plastic|  1 Year|Manufacturer A|     4|          13.25|            2|      25|        true|        40.58|             GLS|     Standard|    Basic|      30 Days|
# |2014-11-26| 26| November|2014|          19|         Youth (<25)|              M|   Canada|British Columbia|     Accessories|  Bike Racks|Hitch Rack - 4-Bike|             8|       45|       120|   590| 360|    950|Extra Large|White|       Steel| 2 Years|Manufacturer A|     5|           4.56|            4|       1|        true|        95.32|           Posti|     Same Day|     None|      30 Days|
# |2019-03-23| 23|    March|2019|          49|      Adults (35-64)|              M|Australia| New South Wales|     Accessories|  Bike Racks|Hitch Rack - 4-Bike|            23|       45|       120|  1366|1035|   2401|      Small|Green|       Steel|  1 Year|Manufacturer D|     3|           8.97|            1|       0|        true|        74.54|             GLS|      Express|  Premium|       7 Days|
# |2015-03-23| 23|    March|2015|          49|      Adults (35-64)|              M|Australia| New South Wales|     Accessories|  Bike Racks|Hitch Rack - 4-Bike
     Accessories|  Bike Racks|Hitch Rack - 4-Bike|             2|       45|       120|   148|  90|    238|      Large|Green|     Plastic| 2 Years|Manufacturer A|     4|          10.97|            6|       4|        true|         33.9|             GLS|     Same Day|     None|      30 Days|
# |2022-09-02|  2|September|2022|          29|Young Adults (25-34)|              M|   Canada|British Columbia|     Accessories|  Bike Racks|Hitch Rack - 4-Bike|             1|       45|       120|    74|  45|    119|Extra Large|White|    Aluminum| 3 Years|Manufacturer D|     5|           9.03|            8|       0|       false|        54.85|             DHL|      Express|    Basic|       7 Days|
# |2016-01-22| 22|  January|2016|          29|Young Adults (25-34)|              M|   Canada|British Columbia|     Accessories|  Bike Racks|Hitch Rack - 4-Bike|             1|       45|       120|    74|  45|    119|      Large|White|Carbon Fiber| 3 Years|Manufacturer A|     1|           2.99|            6|      15|       false|        46.03|           Posti|      Express|    Basic|      60 Days|
# |2016-01-22| 22|  January|2016|          29|Young Adults (25-34)|              M|   Canada|British Columbia|     Accessories|  Bike Racks|Hitch Rack - 4-Bike|             1|       45|       120|    74|  45|    119|Extra Large|Black|     Plastic|Lifetime|Manufacturer B|     4|           4.39|            3|      15|       false|        32.67|             UPS|     Next Day|    Basic|       7 Days|
# +----------+---+---------+----+------------+--------------------+---------------+---------+----------------+----------------+------------+-------------------+--------------+---------+----------+------+----+-------+-----------+-----+------------+--------+--------------+------+---------------+-------------+--------+------------+-------------+----------------+-------------+---------+-------------+
# only showing top 20 rows

# %%
#Creamos una nueva variable "df_select" donde almacenara las columnas deseadas (Date,Customer_Age,Country,Product_Category,Unit_Price_Color)
df_select = df.select(df.Date,df.Customer_Age,df.Customer_Gender,df.Country,df.Product_Category,df.Unit_Price,df.Color)
df_select.show()
# Out:
# +----------+------------+---------------+---------+----------------+----------+-----+
# |      Date|Customer_Age|Customer_Gender|  Country|Product_Category|Unit_Price|Color|
# +----------+------------+---------------+---------+----------------+----------+-----+
# |2017-11-26|          19|              M|   Canada|     Accessories|       120|White|
# |2014-11-26|          19|              M|   Canada|     Accessories|       120|White|
# |2019-03-23|          49|              M|Australia|     Accessories|       120|Green|
# |2015-03-23|          49|              M|Australia|     Accessories|       120|  Red|
# |2018-05-15|          47|              F|Australia|     Accessories|       120| Blue|
# |2023-05-15|          47|              F|Australia|     Accessories|       120|Green|
# |2015-05-22|          47|              F|Australia|     Accessories|       120|Green|
# |2014-05-22|          47|              F|Australia|     Accessories|       120|  Red|
# |2021-02-22|          35|              M|Australia|     Accessories|       120| Blue|
# |2023-02-22|          35|              M|Australia|     Accessories|       120| Blue|
# |2015-07-30|          32|              F|Australia|     Accessories|       120|White|
# |2019-07-30|          32|              F|Australia|     Accessories|       120|Black|
# |2021-07-15|          34|              M|Australia|     Accessories|       120| Blue|
# |2020-07-15|          34|              M|Australia|     Accessories|       120|Black|
# |2020-08-02|          29|              M|   Canada|     Accessories|       120|  Red|
# |2013-08-02|          29|              M|   Canada|     Accessories|       120|White|
# |2014-09-02|          29|              M|   Canada|     Accessories|       120|Green|
# |2022-09-02|          29|              M|   Canada|     Accessories|       120|White|
# |2016-01-22|          29|              M|   Canada|     Accessories|       120|White|
# |2016-01-22|          29|              M|   Canada|     Accessories|       120|Black|
# +----------+------------+---------------+---------+----------------+----------+-----+
# only showing top 20 rows

# %%
# Filtrar con múltiples condiciones mostrando precios mayores a "10" y unicamnete del Country "Germany"
data_filtered = df_select.filter((df_select.Unit_Price > 10) & (df_select.Country == "Germany"))
data_filtered.show()
# Out:
# +----------+------------+---------------+-------+----------------+----------+-----+
# |      Date|Customer_Age|Customer_Gender|Country|Product_Category|Unit_Price|Color|
# +----------+------------+---------------+-------+----------------+----------+-----+
# |2022-08-07|          38|              M|Germany|     Accessories|       120|Black|
# |2015-08-07|          38|              M|Germany|     Accessories|       120| Blue|
# |2017-09-25|          19|              F|Germany|     Accessories|       120|White|
# |2019-09-25|          19|              F|Germany|     Accessories|       120|Black|
# |2013-09-23|          41|              F|Germany|     Accessories|       120| Blue|
# |2021-09-23|          41|              F|Germany|     Accessories|       120|White|
# |2017-02-19|          87|              F|Germany|     Accessories|       120|White|
# |2023-02-19|          87|              F|Germany|     Accessories|       120|Black|
# |2016-12-09|          25|              F|Germany|     Accessories|       120|Black|
# |2017-12-09|          25|              F|Germany|     Accessories|       120| Blue|
# |2017-05-17|          31|              F|Germany|     Accessories|       120|Black|
# |2014-05-17|          31|              F|Germany|     Accessories|       120| Blue|
# |2022-07-31|          23|              M|Germany|     Accessories|       120|  Red|
# |2021-07-31|          23|              M|Germany|     Accessories|       120|Green|
# |2019-06-06|          28|              F|Germany|     Accessories|       120|White|
# |2020-06-06|          28|              F|Germany|     Accessories|       120|  Red|
# |2023-07-12|          50|              M|Germany|     Accessories|       120|White|
# |2019-07-12|          50|              M|Germany|     Accessories|       120|Black|
# |2023-07-15|          32|              F|Germany|     Accessories|       120|Black|
# |2023-07-15|          32|              F|Germany|     Accessories|       120|Green|
# +----------+------------+---------------+-------+----------------+----------+-----+
# only showing top 20 rows

# %%
#Por ultimo ordenamos la nueva tabla por la columna "Custormer_Age" para ver la edad mayor de nuestro comprador
data_order = data_filtered.orderBy(df.Customer_Age,ascending = False)
data_order.show()
# Out:
# +----------+------------+---------------+-------+----------------+----------+-----+
# |      Date|Customer_Age|Customer_Gender|Country|Product_Category|Unit_Price|Color|
# +----------+------------+---------------+-------+----------------+----------+-----+
# |2017-02-19|          87|              F|Germany|     Accessories|       120|White|
# |2017-02-19|          87|              F|Germany|     Accessories|       120|White|
# |2023-02-19|          87|              F|Germany|     Accessories|       120|Black|
# |2023-02-19|          87|              F|Germany|     Accessories|       120|Black|
# |2018-03-05|          86|              M|Germany|        Clothing|        64|  Red|
# |2020-03-05|          86|              M|Germany|     Accessories|        22|Green|
# |2019-03-05|          86|              M|Germany|        Clothing|        64|Green|
# |2013-03-05|          86|              M|Germany|     Accessories|        22|White|
# |2018-11-22|          85|              M|Germany|     Accessories|        25|Black|
# |2019-11-22|          85|              M|Germany|     Accessories|        35| Blue|
# |2015-11-22|          85|              M|Germany|     Accessories|        25|Green|
# |2014-11-22|          85|              M|Germany|     Accessories|        35|White|
# |2021-11-22|          85|              M|Germany|     Accessories|        25|Black|
# |2023-11-22|          85|              M|Germany|     Accessories|        25|White|
# |2021-04-19|          81|              F|Germany|     Accessories|        35|  Red|
# |2014-04-19|          81|              F|Germany|     Accessories|        35|  Red|
# |2023-07-22|          77|              F|Germany|        Clothing|        64| Blue|
# |2018-07-22|          77|              F|Germany|     Accessories|        22| Blue|
# |2015-07-22|          77|              F|Germany|        Clothing|        64|Black|
# |2022-07-22|          77|              F|Germany|     Accessories|        22|  Red|
# +----------+------------+---------------+-------+----------------+----------+-----+
# only showing top 20 rows

# %%
#Guardamos nuestra nueva tabla con todos los ajustes hechos anteriormente
data_order.write.csv("/content/data_set_order", header=True, mode='overwrite')

# %%
#Por ultimo finalizamos Spark
spark.stop()
